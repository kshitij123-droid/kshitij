# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
'''download haberman.csv dataset from https://www.kaggle.com/gilsousa/habermans-survival-data-set/version/1'''
#Load haberman.csv in pandas dataFrame
haberman =pd.read_csv("haberman.csv")

# %%
#How many data-points and features
print (haberman.shape)
# Out:
# (306, 4)

# %%
#What are the column names in our dataset?
print(haberman.columns)
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
haberman["status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# identifies datasets under category of survival status attribute
# where status attribute 1 where patient survived 5yrs or longer .status attribute 2 where patient died in less than 5 yrs

# %%
#2-D scatter plot
haberman.plot(kind='scatter',x='age',y='nodes',label='status');
plt.legend(loc='upper left')
plt.show()
# one cannot make out of this plot to differentiate number of  patients based on status 1 and status 2, due to same color

# %%
sns.set_style("whitegrid");
sns.FacetGrid(haberman,hue="status",size=3)\
   .map(plt.scatter,"age","nodes")\
   .add_legend();
plt.title('patients age vs nodes based on status 1 and status 2')
plt.show();

# %% [markdown]
# 2-D scatter plot  with color coding for each status attribute,here sns corresponds to seaborn

# %% [markdown]
# This plot explains relationship between age of patients and number of axillary nodes patients have and their demarcation based on status 1 and status 2.
#
# Under 40 years there is 1 patient of status 1 with 30 nodes ,3 patients with status 1 in range of 10-20 nodes majority of patients of status 1 lie node range 0-10,3 patients of status 2 lie in this node range 0-10...
#
# Even  they overlap on patients of status 1 in this range but still can be differentiated from patients of status 1
# age range 40-60 years there are two patients status 2 with nodes 35 and 52 respectively.
#
# There is one patient with status 1 with 47 nodes,node range 13-30 within the age range 40-60 except few overlaps, there is demarcation of patients with status 1 and status 2.
#
# patients falling in node range 0-13 within age range 40-60 cannot be clearly demarcated on basis of status 1 and 2 due to multiple overlaps.
#
# Age range 60-80 years with node range 20-30 there are 3 patients on status 1 and one patient of status 2 is overlapped with a patient of status 1 with 22 nodes.
#
# The node range 10-20 with age range 60-80 there are 5 patients of status 2 and one patient of status 1.
#
# The node range 5-10 with age range 60-80 there are 4 patients of status 1 and 3 patients of status 2 where 2 patients of status 2 overlap a patient of status 1 with 8 nodes.
#
# Node range 0-5 with age range 60-80 one cannot clealry demarcate patients of status 1 and status 2,Above age of 80yrs there is a patient of status 2 with 3 nodes

# %% [markdown]
# Observations:-
# Based on above plot among the patients who have 10 auxilary nodes or more there is clear demarcation of categories of patients who were able to survive more than 5 years and those patients who were  able to survive less than 5 years respectively.
#
# Among the two catgeories of patients having auxilary nodes 10 or more ,there are more number of patients who were  able to survive less than 5 years compared to those patients who were able to survive more than 5 years

# %%
sns.FacetGrid(haberman,hue="status",size=3)\
   .map(plt.scatter,"nodes","year")\
   .add_legend();
plt.title('patients number of auxilary nodes vs year of operation based on status 1 and status 2')
plt.show();

# %% [markdown]
# FacetGrid class shows multiple axes arrayed in a grid of rows and columns,which corresponds to the  levels of variables in dataset

# %% [markdown]
# This plot explains relationship between auxillary nodes of the patients of status 1 and staus 2 respectively,
# and the year in which the patients were operated
# There is no clear demarcation of patients of status 1 and status 2 in this relationship

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(haberman,hue="status",size=3,diag_kind="kde",vars=["age","year","nodes"]);
plt.show();

# %% [markdown]
# Pairplot class will create a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.

# %% [markdown]
# There is clear demarcation of patients of status 1 and status 2 ,in which year they have been operated for cancer
#
# There is clear demarcation of patients of status 1 and status 2,how many nodes each patient has.
#
# There is demarcation of patients of status 1 and status 2, for age increases 0 to 80 but as the age decreases from 80 to 0 there is no clear demaraction of patients of status 1 and status 2.

# %% [markdown]
# Observations:-The higher age range 60-80yrs  of patients who have survived less than 5 years are more in number than the patients who have survived ,pre thn 5 years
# The patients with higher number of node range 10-50 of patients who have survived more than 5 years are more in number than the patients who have survived less than 5 years.

# %%
sns.FacetGrid(haberman,hue="status",size=3)\
   .map(sns.distplot,"age")\
   .add_legend();
plt.ylabel('PDF of patients')
plt.title('probability density function of patients vs age of patients on the basis of status 1 and status 2')
plt.show();

# %% [markdown]
# Distplot function has following properties:-
# 1)It draws graphical distribution plot with automatic calculation of good bin size by default
# 2)It shows a univariate or bivariate distribution with a kernel distribution estimate
# 3)It draws small vertical lines to show each observation in a distribution

# %% [markdown]
# The probability density functions of patients with status 1 and status 2 have clear demarcation in age range 20-60 yrs
# The probability density fucntions of patients with status 1 and status 2 don't have clear demarcation in age range 60-80yrs
# The probability density fucntions of patients with status 1 and status 2 have clear demarcation in age range 80-100 years

# %% [markdown]
# Observations:- among patients of age range 20-40 years the number of patients ,who have survived more than 5 yrs,
# are more than the number of the patients who have survived less than 5 yrs
# among patients of age range 40-60 the  number of patients ,who have survived more than 5 yrs,
# are less than the number of the patients who have survived less than 5 yrs
# among patients of age range 80-100yrs  the  number of patients ,who have survived more than 5 yrs
# are more than the number of the patients who have survived less than 5 yrs

# %%
sns.FacetGrid(haberman,hue="status",size=3)\
   .map(sns.distplot,"year")\
   .add_legend();
plt.ylabel('PDF of patients')
plt.title('probability density function of patients vs year of operation on the basis of status 1 and status 2')
plt.show();

# %% [markdown]
# The  probability density functions of patients of status 1 and status 2 have clear demarcation from year range 1953-80
# except during specific years during which they overlap

# %% [markdown]
# Observations:- among patients  who were operated for cancer in year range 1955-58,who have survived more than 5 years ,
# are more than the number of patients who survived less than 5 yrs.
#
# Among patients  who were operated for cancer in year range 1958-63,who have survived more than 5 years,
# less in number than those patients who survived less than 5 yrs.
#
# Among patients  who were operated for cancer in year range 1963-67,who have survived more than 5 years ,
# are more than the number of patients who survived less than 5 yrs

# %%
sns.FacetGrid(haberman,hue="status",size=3)\
   .map(sns.distplot,"nodes")\
   .add_legend();
plt.ylabel('PDF of patients')
plt.title('probability density function of patients vs number of auxialry nodes  on the basis of status 1 and status 2')
plt.show();

# %% [markdown]
# The  probability density function of patients with of status 1 was on higher side nearby 0 nodes compared to the probability density function of patients of status 2.
#
# The  probability density functions of patients of status 1 and status 2 within node range 10-30 were on lesser side,
# but still difference in the  probability density functions of patients for status 1 and status 2 are clearly visible.

# %%
sns.boxplot(x='status',y='age',data=haberman)
plt.title(' comparison of age percentile distribution of patients based on status 1 and status 2')
plt.show()

# %% [markdown]
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable.
#
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %% [markdown]
# This plot explains status 1 patients of age range 45-60,this age range represents 25th-75th percentiles,
# with lower limit -30 years being 0 percentile and upper limit-78 years,being 100 percentile.
#
# status 1 patients with 54 years represents 50th percentile. Majority of status 1 patients lie in age range 25th-75th percentiles.
#
# status 2 patients average age range 46-62 years which is 25th-75th percentile,
# where lower limit -35years which represents 0 percentile and upper limit -82 years which represents 100 percentile.

# %% [markdown]
# Observations:-The patients who have survived less than 5 years of highest age limit is higher than the patients who have  survived more than 5 years of of highest age limit

# %%
sns.boxplot(x='status',y='nodes',data=haberman)
plt.title(' comparison of number of nodes percentile distribution of patients based on status 1 and status 2')
plt.show()

# %% [markdown]
# This plot explains status 1 patients with average node range 0-4 where it's difficult to differentiate lower limit-0 percentile
# with start point of avergae node range limit-25 percentile,also it's difficult to differentiate node vallue corresponinding 50th percentile in this plot.
#
# The upper limit is node value 8 nearing to 100 percentile,as there are some individual patients with specific node value
# where patient with highest node value-45 corresponds to 100 percentile.
#
# status 2 patient explians lower limit node value as 0 which corresponds to 0 percentile,average node value-1-11(25th-75th percentile),here there is marginal difference between oth percentile and 25th percentile resepctively.
#
# status 2 patient of node value:-5 corresponds to 50th percentile and status 2 patient's upper limit node value:-25 is nearest to 100 percentile,with individual status 2 patient of node value-52 corresponds to 100 percentile.

# %% [markdown]
# observations:- Median nodes for those who have survived more than 5 years  are less compared to those who have survived less than 5 years.
#
# Also, one can observe many outliers in nodes for those who have survived.
#
# Also, the variance of nodes is more for those who have survived less than 5 years compared to those who have survived more than 5 years

# %%
sns.boxplot(x='status',y='year',data=haberman)
plt.title(' comparison of operation year percentile distribution of patients based on status 1 and status 2')
plt.show()

# %% [markdown]
# This plot explains status 1 patients with lower limit year-1958,corresponds to 0 percentile, starting year in 1958-70 range,when the patient was operated,average year range 1960-66,corresponds to 25th-75th percentile with the status 1 patient operated in year 1963 corresponds to 50th percentile.
#
# The upper limit being year 1970 which corresponds to 100 percentile,similarly status 2 patients have same year lower limit -1958 which corresponds to 0 percentile and upper limit year as 1970 which corresponds to 100 percentile.
#
# The average year range for status 2 patient is 1959-65 which corresponds to 25th-75th percentile.

# %% [markdown]
# observations:-
# The variance spread of the year when the patients, who were operated, who have survived less than 5 years  is bit on lesser side compared to variance spread of the year when patients were operated,who have survived more than 5 years.

# %%
sns.violinplot(x='status',y='age',data=haberman,size=8)
plt.title(' comparison of age distribution of patients based on status 1 and status 2')
plt.show()
sns.violinplot(x='status',y='year',data=haberman,size=8)
plt.title(' comparison of year distribution of patients based on status 1 and status 2')
plt.show()
sns.violinplot(x='status',y='nodes',data=haberman,size=8)
plt.title(' comparison of  nodes distribution of patients based on status 1 and status 2')
plt.show()

# %% [markdown]
# Violen plot is a combination of boxplot and kernel density estimate.
# It features a kernel density estimation of the underlying distribution

# %% [markdown]
# violin plots are combination of probability desnity function which is the fatter and thhiner colors regions for status 1 and staus 2 patients respectively and the black line with white pointer respresents box plots

# %% [markdown]
# Observations:-
# The patients who survived less than 5 years have highest number of auxilary nodes compared to patients who survived more than 5 years.

# %%
df=pd.read_csv('haberman.csv')
df.age[df.status==1]
df.nodes[df.status==1]
print("Means:")
print(np.mean(df.age[df.status==1]))
print(np.mean(df.nodes[df.status==1]))
print("standard deviation:")
print(np.std(df.age[df.status==1]))
print(np.std(df.nodes[df.status==1]))
# Out:
# Means:
# 52.01777777777778
# 2.7911111111111113
# standard deviation:
# 10.98765547510051
# 5.857258449412131

# %% [markdown]
# The mean age and standard deviation age  of status 1 patients are 52.01 and 10.98 respectively
# The mean node and standard deviation of nodes of status 1 patients are 2.79 and 5.85 respectively

# %%
df.age[df.status==2]
df.nodes[df.status==2]
print("Means:")
print(np.mean(df.age[df.status==2]))
print(np.mean(df.nodes[df.status==2]))
print("standard deviation:")
print(np.std(df.age[df.status==2]))
print(np.std(df.nodes[df.status==2]))
# Out:
# Means:
# 53.67901234567901
# 7.45679012345679
# standard deviation:
# 10.10418219303131
# 9.128776076761632

# %% [markdown]
# The mean age and standard deviation age  of status 2 patients are 53.67 and 10.10 respectively
# The mean node and standard deviation node  of status 2 patients are 7.45 and 9.12 respectively

# %% [markdown]
# Observations:-
# The mean age of the number of patients who have survived more than 5 yrs is less than number of patients who have survived for less than 5 yrs.
#
# The standard deviation age of the number of patients who have survived mire than 5 yrs is slightly higher than number of patients who have survived for less than 5 yrs
#
# The Mean node of the number of patients who have survived more than 5 yrs is less than number of patients who have survived for less than 5 yrs
#
# The standard deviation node of  the number of patients who have survived more than 5 yrs is less thannumber of patients who have survived for less than 5 yrs

# %% [markdown]
# Conclusion:- the number of patients who survived more than 5 years were more in number compared to number of patients who survived for less than 5 years, when  the parameters age range and year of operation of cancer
